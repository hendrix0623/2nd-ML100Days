# %% [markdown]
# 作業1：
#
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
#
# # 1. 你選的這組資料為何重要
# Ans:
# 選取資料：
# Stack Overflow Data 程式設計人員的社群問答網站
# https://www.kaggle.com/stackoverflow/stackoverflow
#
# 可藉由分析相關使用者問答的行為，以找出相關問題解決方式的聯關脈絡
#
# # 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
# Ans:
# 提供者：
# StackOverFlow官方
# 蒐集方式：
# 所有使用者的問題貼文、投票、標籤、跟徽章...等相關文章訊息
#
# # 3. 蒐集而來的資料型態為何
# Ans:
# 結構化關聯式資料 (BigQuery Dataset)
#
# # 4. 這組資料想解決的問題如何評估
# Ans: 歸納分類所有標籤資訊，並找出所有標籤的關聯性(使用者從發問至結束發問為一個最小單位的脈絡)，然後統整所有脈絡資訊並再次分類比對

# %% [markdown]
# 作業2：
#
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# ## 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
# Ans:
# 如何在"天氣晴"的狀況下，提升都會地區的整體載客率
#
# 在雨天的狀況下，通常載客需要總是供不應求，
# 但在晴天的壯狀況下，如何透過觀察一些可影響載客率的因子，以增加晴天時段的業績
# ex:
# 優惠活動
# 特殊加強布點路段(工作機關、商場)
# 特殊加強布點時段(假日、上下班、特別活動)
#
# ## 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
# Ans:
# 每位司機晴/雨日載客收入資料 (使用自家開發APP收集)
# 每位司機晴/雨日載客每趟上下車地點  (使用自家開發APP收集)
# 氣象局即時氣象特報  (政府開放資料平台)
# 交通忙碌資訊 from Google Map (Goole developer API)
# 地理忙碌資訊 from Google Map (Goole developer API)
#
# ## 3. 蒐集而來的資料型態為何
# Ans:
# 每位司機晴/雨日載客收入資料 (結構化資料)
# 氣象局即時氣象特報  (json)
# Google Map (json)
#
# ## 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
# Ans:
# 將晴天時段定義出來，在每個晴天時段觀察每位司機、收入、載客點、路線、及其周邊環境建物，綜合比較找出一(數)個最佳的運行收入模式。

# %% [raw]
# 練習時間
# 請寫一個函式用來計算 Mean Square Error
# 𝑀𝑆𝐸=1𝑛∑𝑛𝑖=1(𝑌𝑖−𝑌̂ 𝑖)2
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y, yhat):
    """
    請完成這個 Function 後往下執行
    """
    n = len(y)
    mse = sum(np.square(y-yhat))/n
    return mse

def mean_absolute_error(y, yhat):

    n=len(y)
    mae= sum(np.abs(y-yhat))/n
    return mae

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 213.169
# The Mean absolute error is 11.667
